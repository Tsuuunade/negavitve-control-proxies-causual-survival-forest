# %% [markdown]
# # Parameter tunning

# %% [markdown]
# ### proxy strength (more or less informative about U): sigma_z, sigma_v

# %% [markdown]
# | Corr(Z, U) | σ (sigma) |
# |------------|-----------|
# | 0.9        | 0.73      |
# | 0.8        | 1.125     |
# | 0.7        | 1.53      |
# | 0.6        | 2.0       |
# | 0.5        | 2.6       |
# | 0.4        | 3.44      |
# | 0.3        | 4.77      |
# | 0.2        | 7.35      |
# | 0.1        | 14.93     |
#
# * we fix $a_z, a_v = 1.5$ for all cases.
# * The table for sigma_v are the same as sigma_z.

# %% [markdown]
# ### strength of confounding (how much U affects treatment assignment A and outcome T): gamma_u_in_a, beta_u_in_t

# %% [markdown]
# | level    | gamma_u_in_a | beta_u_in_t |
# |----------|---------|--------|
# | none     | 0.0     | 0.0    |
# | weak     | 0.2     | 0.2    |
# | moderate | 0.5     | 0.5    |
# | strong   | 1.0     | 1.0    |
# | extreme  | 2.0     | 2.0    |

# %% [markdown]
# ### strength of treatment effect: tau_log_hr

# %% [markdown]
# | tau_log_hr value | Interpretation                          |
# |------------------|------------------------------------------|
# | 0                | No treatment effect                      |
# | < 0              | Beneficial (lower hazard)      |
# | > 0              | Harmful (higher hazard)        |
#
# **possible range**
#
# | Effect size category        | tau_log_hr range | Hazard ratio range (exp(tau)) | Interpretation |
# |----------------------------|------------------|-------------------------------|----------------|
# | Null / negligible          | [-0.1, 0.1]      | [0.90, 1.11]                  | Little to no effect |
# | Small to moderate (typical)| [-0.3, 0.3]      | [0.74, 1.35]                  | Plausible clinical effects |
# | Moderate to large          | [-0.7, 0.7]      | [0.50, 2.01]                  | Strong but still realistic |
# | Extreme (use with caution) | < -1 or > 1      | < 0.37 or > 2.7               | Often unrealistic / unstable |

# %% [markdown]
# # Testing

# %%
# Add parent directory to Python path to import nc_csf module
import sys
from pathlib import Path

# Get the root directory (where nc_csf folder is located)
# Need to go up two levels: synthetic data -> non_cencoring -> root
root_dir = Path.cwd().parent.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))
    
print(f"Added to path: {root_dir}")
# Out:
# Added to path: c:\Users\17414\OneDrive\桌面\USC\negavitve-control-proxies-causual-survival-forest

# %%
from nc_csf.evaluate_performance import run_experiment

# %% [markdown]
# ## Linear in treatment and outcome

# %% [markdown]
# ### Informative proxies & strong confounding & harmful large treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=-0.7,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=True, linear_outcome=True
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE     Slope
#  Baseline with X only 0.496308 0.339909 -0.339720  -0.168692   -0.094195  1.415968 -0.023288
# Baseline with X, Z, W 0.391892 0.213205 -0.189599   0.208743    0.337106  1.118068  0.036833
#                NC-CSF 0.378904 0.205822 -0.142946   0.063929    0.159444  1.081014  0.009191
#                Oracle 0.332135 0.209625  0.002292   0.353284    0.440229  0.947581  0.071658

# %% [markdown]
# ### Informative proxies & weak confounding & benificial small treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.2,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.25,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=True, linear_outcome=True
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.040220 0.033240 -0.027184   0.748104    0.722730  0.933914 0.696913
# Baseline with X, Z, W 0.040213 0.032432 -0.025144   0.726446    0.692692  0.933745 0.704245
#                NC-CSF 0.033560 0.025973 -0.010052   0.687433    0.601285  0.779270 0.582397
#                Oracle 0.033877 0.025445 -0.004949   0.644076    0.549941  0.786629 0.507196

# %% [markdown]
# ### Non informative proxies & strong confounding & benificial moderate treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.5,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=True, linear_outcome=True
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.282963 0.253840 -0.231789   0.423918    0.510157  1.693566 0.328786
# Baseline with X, Z, W 0.168043 0.132859 -0.094843   0.563490    0.723323  1.005756 0.364375
#                NC-CSF 0.164674 0.119518 -0.051297   0.374249    0.447369  0.985593 0.189266
#                Oracle 0.156690 0.093355  0.011802   0.354808    0.411814  0.937808 0.119011

# %% [markdown]
# ### Non informative proxies & weak confounding & near null treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.25,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.12,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=True, linear_outcome=True
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.039114 0.029207 -0.026392   0.655704    0.565168  1.813530 1.155425
# Baseline with X, Z, W 0.033115 0.023517 -0.019089   0.664313    0.558563  1.535366 1.111439
#                NC-CSF 0.024799 0.018648 -0.002665   0.494575    0.294357  1.149784 0.612244
#                Oracle 0.024334 0.017809  0.002803   0.480253    0.268349  1.128239 0.566054

# %% [markdown]
# ## Non linear in only outcome

# %% [markdown]
# ### Informative proxies & strong confounding & harmful large treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=-0.7,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=True, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE     Slope
#  Baseline with X only 0.496513 0.342175 -0.342056  -0.160847   -0.123777  1.424314 -0.022857
# Baseline with X, Z, W 0.394348 0.212685 -0.194942   0.186760    0.256327  1.131241  0.026841
#                NC-CSF 0.381224 0.203886 -0.150949   0.030875    0.086503  1.093591  0.003948
#                Oracle 0.332703 0.203359 -0.007469   0.335242    0.428823  0.954402  0.061796

# %% [markdown]
# ### Informative proxies & weak confounding & benificial small treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.2,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.3,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=True, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.042587 0.034949 -0.027328   0.754424    0.751251  0.863578 0.636370
# Baseline with X, Z, W 0.039657 0.032023 -0.021836   0.743314    0.752719  0.804163 0.594580
#                NC-CSF 0.038894 0.029488 -0.009509   0.646470    0.616435  0.788676 0.452140
#                Oracle 0.039178 0.028647 -0.002817   0.610033    0.545412  0.794436 0.373804

# %% [markdown]
# ### Non informative proxies & strong confounding & benificial moderate treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.5,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=True, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.276802 0.251208 -0.227190   0.403639    0.492608  1.665769 0.268712
# Baseline with X, Z, W 0.163370 0.129017 -0.092487   0.586671    0.734200  0.983149 0.362865
#                NC-CSF 0.162536 0.116540 -0.047674   0.364520    0.440365  0.978125 0.164116
#                Oracle 0.157451 0.092861  0.009924   0.326194    0.388591  0.947528 0.098183

# %% [markdown]
# ### Non informative proxies & weak confounding & near null treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.25,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.12,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=True, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.040328 0.031354 -0.029507   0.617476    0.536994  1.928034 1.032079
# Baseline with X, Z, W 0.031766 0.023352 -0.019096   0.608902    0.517486  1.518698 0.930685
#                NC-CSF 0.026770 0.019991 -0.002353   0.352333    0.210643  1.279865 0.429459
#                Oracle 0.026085 0.018697  0.004095   0.329271    0.192499  1.247100 0.369049

# %% [markdown]
# ## Non linear in treatment & outcome

# %% [markdown]
# ### Informative proxies & strong confounding & harmful large treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=-0.7,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=False, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.396956 0.188910 -0.082611   0.325780    0.386640  0.968955 0.084718
# Baseline with X, Z, W 0.361915 0.177847 -0.022770   0.487548    0.572038  0.883422 0.178015
#                NC-CSF 0.387449 0.201708 -0.021854   0.330873    0.392647  0.945750 0.120404
#                Oracle 0.385622 0.203995 -0.001045   0.352094    0.437856  0.941289 0.088841

# %% [markdown]
# ### Informative proxies & weak confounding & benificial small treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.2,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.3,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=1.125, aW=1.5, sigma_w=1.53,
    linear_treatment=False, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.041192 0.032755 -0.021772   0.686835    0.707964  0.866380 0.549372
# Baseline with X, Z, W 0.037402 0.029118 -0.016245   0.706686    0.736915  0.786659 0.472438
#                NC-CSF 0.039893 0.031214 -0.018214   0.671102    0.683642  0.839058 0.509372
#                Oracle 0.037286 0.028653 -0.015144   0.699930    0.700559  0.784217 0.531302

# %% [markdown]
# ### Non informative proxies & strong confounding & benificial moderate treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.9,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.5,beta_u_in_t=1.1,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=False, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.192792 0.122683 -0.043378   0.281871    0.386562  0.987239 0.060062
# Baseline with X, Z, W 0.168668 0.082265  0.003397   0.517266    0.663731  0.863706 0.208162
#                NC-CSF 0.193433 0.101934  0.006807   0.148196    0.249470  0.990521 0.028404
#                Oracle 0.189511 0.096790  0.012774   0.255350    0.353326  0.970435 0.052045

# %% [markdown]
# ### Non informative proxies & weak confounding & near null treatment effect

# %%
results_df, cate_te, pred_baseline, pred_nccsf, pred_oracle = run_experiment(
    n=5000, p_x=10, seed=123,
    a_prevalence=0.5, gamma_u_in_a=0.25,
    k_t=1.5, lam_t=0.4, tau_log_hr=0.12,beta_u_in_t=0.2,
    k_c=1.2, lam_c=1e6, beta_u_in_c=0.3, target_censor_rate=0, max_censor_calib_iter=60, censor_lam_lo=1e-8,censor_lam_hi=1e6, admin_censor_time=None,
    aZ=1.5, sigma_z=7.35, aW=1.5, sigma_w=4.77,
    linear_treatment=False, linear_outcome=False
)

print("\nEvaluation Results:")
print(results_df.to_string(index=False))
# Out:
# Evaluation Results:
#                 Model     RMSE      MAE      Bias  Pearson r  Spearman r  Rel RMSE    Slope
#  Baseline with X only 0.032937 0.026148 -0.023824   0.666212    0.645017  1.633305 1.008145
# Baseline with X, Z, W 0.029824 0.023928 -0.022314   0.691019    0.677998  1.478937 0.936686
#                NC-CSF 0.030371 0.023943 -0.020453   0.608005    0.588776  1.506065 0.844786
#                Oracle 0.028994 0.022750 -0.019074   0.629300    0.593382  1.437773 0.871120
